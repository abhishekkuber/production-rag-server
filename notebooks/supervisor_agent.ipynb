# %%
import sys
import os
from pathlib import Path

# Add the project root to Python path
cwd = Path().resolve()
if cwd.name == "notebooks":
	project_root = cwd.parent
else:
	project_root = cwd

if str(project_root) not in sys.path:
	sys.path.insert(0, str(project_root))

# %%
from langchain.agents import create_agent
from langchain.tools import tool
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_tavily import TavilySearch
from src.rag.retrieval.index import retrieve_context_and_build_prompt
from src.rag.retrieval.utils import prepare_prompt_and_invoke_llm
from src.config.index import app_config
import json
from langgraph.graph import MessagesState
from typing import Any, List, Dict
from typing_extensions import Annotated
from langgraph.types import Command
from langchain_core.tools.base import InjectedToolCallId
from langchain_core.messages import ToolMessage
from langchain_core.runnables import RunnableConfig
from datetime import datetime

# %%
os.getenv("TAVILY_API_KEY")
# Out:
# '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'

# %%
# Custom Agent State to track citations
class CustomAgentState(MessagesState):
	"""Extended agent state with citations tracking"""
	citations: Annotated[List[Dict[str, Any]], lambda x, y: x + y] = []

# %%
# Create a RAG search tool bound to a specific project
def create_rag_tool(project_id: str):
	"""Create a RAG search tool bound to a specific project"""
	
	@tool
	def rag_search(
		query: str,
		tool_call_id: Annotated[str, InjectedToolCallId],
	) -> Command:
		"""
		Search through project documents using RAG (Retrieval-Augmented Generation).
		This tool retrieves relevant context from the current project's documents based on the query.
		
		Args:
			query: The search query or question to find relevant information
			
		Returns:
			A formatted string containing the retrieved context and answer based on the documents
		"""
		try:
			# Retrieve context using the existing RAG pipeline
			texts, images, tables, citations = retrieve_context_and_build_prompt(project_id, query)
			
			# If no context found, return a message
			if not texts and not images and not tables:
				return Command(
					update={
						"messages": [
							ToolMessage(
								"No relevant information found in the project documents for this query.",
								tool_call_id=tool_call_id
							)
						]
					}
				)
				
			# Prepare the response using the existing LLM preparation function
			response = prepare_prompt_and_invoke_llm(
				user_query=query,
				texts=texts,
				images=images,
				tables=tables
			)
			
			return Command(
				update={
					"messages": [
						ToolMessage(
							content=response,
							tool_call_id=tool_call_id
						)
					],
					"citations": citations
				}
			)       
		except Exception as e:
			return Command(
				update={
					"messages": [
						ToolMessage(
							f"Error retrieving information: {str(e)}",
							tool_call_id=tool_call_id
						)
					]
				}
			)

	return rag_search

# %%
# Create a RAG agent with a specific project
def create_rag_agent(project_id: str, model: str = "gpt-4o-mini"):
	"""Create an agent with RAG tool for a specific project"""
	
	tools = [create_rag_tool(project_id)]
	
	system_prompt = """You are a helpful AI assistant with access to a RAG (Retrieval-Augmented Generation) tool that searches project-specific documents.

For every user question:

1. Do not assume any question is purely conceptual or general.  
2. Use the `rag_search` tool immediately with a clear and relevant query derived from the user’s question.  
3. Carefully review the retrieved documents and base your entire answer on the RAG results.  
4. If the retrieved information fully answers the user’s question, respond clearly and completely using that information.  
5. If the retrieved information is insufficient or incomplete, explicitly state that and provide helpful suggestions or guidance based on what you found.  
6. Always present answers in a clear, well-structured, and conversational manner.

**Never answer without first querying the RAG tool. This ensures every response is grounded in project-specific context and documentation.**"""
	
	agent = create_agent(
		model=model,
		tools=tools,
		system_prompt=system_prompt,
		state_schema=CustomAgentState
	)
	
	return agent

# %%
# Create a web search agent
def create_web_search_agent(model: str = "gpt-4o-mini", use_tavily: bool = True):
	"""Create an agent with web search capabilities"""
	
	# Choose search tool based on availability
	if use_tavily and os.getenv("TAVILY_API_KEY"):
		search_tool = TavilySearch(max_results=5, search_depth="advanced")
	else:
		# Use DuckDuckGo as free alternative
		search_tool = DuckDuckGoSearchRun()
	
	tools = [search_tool]

	current_date = datetime.now().strftime("%B %d, %Y")  # e.g., "November 25, 2025"

	
	system_prompt = f"""You are a specialized web search assistant.
	Your job is to search the internet for current information and provide accurate, up-to-date answers.

	**Current Date: {current_date}**

	For every query you receive:
	1. **Reformulate vague queries into specific search terms** before searching
	2. Use the web search tool with clear, specific queries
	3. Synthesize information from multiple search results when possible
	4. Provide clear, factual answers with context
	5. Indicate the recency and reliability of information when relevant

	**Query Reformulation Examples:**
	- "What's trending on social media today?" → Try: "Twitter trending topics today" OR "viral news today"
	- "Today's top headlines" → Try: "breaking news today" OR "top news stories {current_date}"
	- "What's happening in tech?" → Try: "latest tech news today" OR "technology headlines today"
	- Add date context when relevant (e.g., "news {current_date}")

	**If initial search returns insufficient or irrelevant results:**
	1. Rephrase the query with more specific terms (e.g., add location, date, or focus area)
	2. Try searching with alternative keywords or synonyms
	3. Make 2-3 search attempts with different query formulations if needed
	4. If still unsuccessful, clearly state what you found vs. what was requested

	Focus on current events, general knowledge, and information not available in internal documents.
	Never fabricate information - only use what's found in search results."""
	
	agent = create_agent(
		model=model,
		tools=tools,
		system_prompt=system_prompt,
		state_schema=CustomAgentState
	)
	
	return agent

# %%
# Wrap sub-agents as tools for the supervisor
def create_supervisor_tools(project_id: str, model: str = "gpt-4o-mini"):
	"""Create supervisor tools that wrap the specialized agents"""
	
	# Create the specialized agents
	rag_agent = create_rag_agent(project_id, model)
	web_agent = create_web_search_agent(model)
	
	@tool
	# def search_project_documents(query: str) -> str:
	def rag_search(
		query: str,
		tool_call_id: Annotated[str, InjectedToolCallId],
	) -> Command:
		"""Search internal project documents using RAG.
		
		Use this when the user asks about:
		- Project-specific information
		- Internal documentation
		- Previously uploaded files and documents
		- Company/project-specific data
		- Technical specifications from project files
		
		Args:
			query: Natural language query about project documents
			
		Returns:
			Relevant information from project documents with citations
		"""
		result = rag_agent.invoke({
			"messages": [{"role": "user", "content": query}]
		})

		final_message = result["messages"][-1]
		content = final_message.content if hasattr(final_message, 'content') else str(final_message)
		citations = result.get("citations", [])
		
		# # Extract the final response
		# final_message = result["messages"][-1]
		# if hasattr(final_message, 'content'):
		# 	return final_message.content
		# return str(final_message)
		# Return Command that updates both messages AND citations
		return Command(
			update={
				"messages": [
					ToolMessage(
						content=content,
						tool_call_id=tool_call_id
					)
				],
				"citations": citations  # ✅ Propagate citations!
			}
		)
	
	@tool
	def search_web(query: str) -> str:
		"""Search the internet for current information.
		
		Use this when the user asks about:
		- Current events or recent news
		- General knowledge not in project documents
		- External information or public data
		- Market trends or industry news
		- Any information that requires up-to-date web sources
		
		Args:
			query: Natural language query for web search
			
		Returns:
			Relevant information from web search results
		"""
		result = web_agent.invoke({
			"messages": [{"role": "user", "content": query}]
		})
		
		# Extract the final response
		final_message = result["messages"][-1]
		if hasattr(final_message, 'content'):
			return final_message.content
		return str(final_message)
	
	return [rag_search, search_web]

# %%
# Create a supervisor agent
def create_supervisor_agent(project_id: str, model: str = "gpt-4o-mini"):
	"""Create a supervisor agent that coordinates RAG and web search agents"""
	
	# Get the supervisor tools (wrapped agents)
	tools = create_supervisor_tools(project_id, model)

	current_date = datetime.now().strftime("%B %d, %Y")  # "November 25, 2025"
	
	system_prompt = f"""You are an intelligent supervisor assistant that coordinates between two specialized agents:

**Current Date: {current_date}**


### Available Agents

1. **Project Documents Agent** (rag_search):
   - Searches internal project documents using RAG
   - Use for project-specific queries, internal documentation, uploaded files

2. **Web Search Agent** (search_web):
   - Searches the internet for current information
   - Use for current events, general knowledge, external information
   - ONLY use this tool if asked by the user or mentioned in the question

### Core Responsibilities

- Analyze user queries and determine which agent(s) to use
- Route queries to the appropriate agent(s) — you MUST NOT answer substantive questions directly
- For complex queries, coordinate multiple agents in sequence
- Synthesize results from multiple agents into coherent answers
- Prioritize project documents for project-specific questions
- Use web search ONLY if asked by the user or mentioned in the question

### Query Routing Rules

**ALWAYS use tools for:**
- Any question requiring factual information
- Project-specific queries
- Technical questions
- Current events or news
- General knowledge questions
- Analysis or research requests

**Direct response permitted ONLY for:**
- Simple greetings (hi, hello, how are you)
- Acknowledgments (thanks, ok, got it)
- Basic clarification requests about your capabilities
- Farewell messages (goodbye, bye)

**ALWAYS use the RAG tool for the questions**
**Return as much information that is given from the RAG tool as possible to the user**

For all other queries, you MUST route to the appropriate agent(s) and synthesize their responses. Your role is coordination and synthesis, not direct knowledge provision.
"""
	
	supervisor = create_agent(
		model=model,
		tools=tools,
		system_prompt=system_prompt,
		state_schema=CustomAgentState
	)
	
	return supervisor

# %%
supervisor = create_supervisor_agent(project_id="3f7be382-9eb8-43ac-8aef-ba437fbaa83f", model="gpt-4o-mini")

# %%
# "Look up current Bitcoin prices online"
# "What's happening in AI this week?"
# "What's happening with AI developments this week?"
# "What are the current flight prices to Paris?"


# What does my document say about black holes, and search for any new black hole discoveries in the last 3 years?

# %%
inputs = {"messages": [{"role": "user", "content": "What does my document say about black holes, and search for any new black hole discoveries in the last 3 years?"}]}

# Stream the response
for chunk in supervisor.stream(inputs, stream_mode="updates"):
	for step, data in chunk.items():
		print(f"step: {step}")
		print(f"content: {data['messages'][-1].content_blocks}")
# Out:
# step: model
# content: [{'type': 'tool_call', 'name': 'rag_search', 'args': {'query': 'What does the document say about black holes?'}, 'id': 'call_hqVSwPi0ot0E20uoibZosN47'}, {'type': 'tool_call', 'name': 'search_web', 'args': {'query': 'new black hole discoveries since 2023'}, 'id': 'call_ACwPCOyqfymuH8RBihylYwyu'}]
#
# ================================================================================
# 📦 CONTEXT VALIDATION
# ================================================================================
#
# 📝 TEXTS: 4 chunks
#
# ================================================================================
# CHUNK [1] - 2526 characters
# ================================================================================
# Dark energy is even more mysterious. It's a form of energy that permeates all of space and causes the expansion of the universe to accelerate. This acceleration was discovered in 1998 by two independent teams studying distant supernovae. The nature of dark energy remains one of the biggest unsolved problems in physics.
#
# === BLACK HOLES ===
#
# Black holes are regions of spacetime where gravity is so strong that nothing, not even light, can escape. They form when massive stars collapse at the end of their lives, or through other processes in the early universe. The boundary of a black hole is called the event horizon, beyond which no information can escape.
#
# There are several types of black holes. Stellar-mass black holes typically have masses between 5 and 100 times the mass of our Sun. Supermassive black holes, found at the centers of most galaxies, can have masses of millions to billions of solar masses. Our Milky Way's central black hole, Sagittarius A*, has a mass of about 4 million solar masses.
#
# In 2019, the Event Horizon Telescope collaboration produced the first direct image of a black hole's shadow, showing the supermassive black hole at the center of the galaxy M87. This achievement confirmed predictions from Einstein's general theory of relativity.
#
# === STARS AND STELLAR EVOLUTION ===
#
# Stars are massive spheres of plasma held together by gravity and powered by nuclear fusion in their cores. They form from collapsing clouds of gas and dust in star-forming regions called molecular clouds or stellar nurseries.
#
# The life cycle of a star depends primarily on its mass. Low-mass stars like our Sun (which is about 4.6 billion years old and halfway through its life) will eventually expand into red giants, shed their outer layers to form planetary nebulae, and end as white dwarfs - hot, dense cores about the size of Earth.
#
# Massive stars live faster and die more dramatically. After exhausting their nuclear fuel, they explode as supernovae, creating and dispersing heavy elements throughout space. These explosions can briefly outshine entire galaxies and leave behind either neutron stars or black holes.
#
# === EXOPLANETS AND THE SEARCH FOR LIFE ===
#
# Exoplanets are planets orbiting stars other than our Sun. The first confirmed detection of an exoplanet around a sun-like star was made in 1995 by Michel Mayor and Didier Queloz, who discovered a planet orbiting the star 51 Pegasi. Since then, thousands of exoplanets have been discovered, revealing a remarkable diversity of planetary systems.
# ================================================================================
#
#
# ================================================================================
# CHUNK [2] - 2582 characters
# ================================================================================
# The Kepler Space Telescope, launched in 2009, revolutionized exoplanet discovery by monitoring hundreds of thousands of stars simultaneously. It discovered that planets are extremely common, with most stars hosting at least one planet. The telescope found many planets in their star's habitable zone, where conditions might allow liquid water to exist on the surface.
#
# The search for extraterrestrial life focuses on finding biosignatures - signs of life that could be detected remotely. These might include certain atmospheric gases produced by life, such as oxygen combined with methane, or technosignatures from advanced civilizations.
#
# === COSMIC PHENOMENA ===
#
# Neutron stars are the collapsed cores of massive stars, typically about 20 kilometers in diameter but containing more mass than our Sun. Some neutron stars are pulsars, rotating rapidly and emitting beams of electromagnetic radiation that sweep across Earth like a cosmic lighthouse. The fastest-known pulsar rotates 716 times per second.
#
# Gamma-ray bursts are the most energetic explosions in the universe, releasing more energy in a few seconds than the Sun will emit in its entire lifetime. They're thought to occur when massive stars collapse into black holes or when neutron stars merge.
#
# Gravitational waves are ripples in spacetime caused by accelerating massive objects. Predicted by Einstein in 1916, they were first directly detected in 2015 by LIGO (Laser Interferometer Gravitational-Wave Observatory) from two merging black holes. This detection opened a new window for observing the universe.
#
# === THE SOLAR SYSTEM ===
#
# Our Solar System formed about 4.6 billion years ago from a rotating cloud of gas and dust. It consists of the Sun, eight planets, five dwarf planets, hundreds of moons, and countless asteroids and comets.
#
# The inner Solar System contains the rocky terrestrial planets: Mercury, Venus, Earth, and Mars. These planets have solid surfaces and are relatively small and dense. Earth is the only known planet with life, protected by its magnetic field and blessed with liquid water on its surface.
#
# The outer Solar System is dominated by the gas giants Jupiter and Saturn, and the ice giants Uranus and Neptune. Jupiter, the largest planet, has a mass greater than all other planets combined and plays a crucial role in protecting the inner Solar System from comet impacts with its powerful gravity.
#
# Beyond Neptune lies the Kuiper Belt, a region of icy bodies including Pluto, and even farther out is the hypothesized Oort Cloud, a spherical shell of comets surrounding the Solar System.
# ================================================================================
#
#
# ================================================================================
# CHUNK [3] - 2723 characters
# ================================================================================
# COSMOLOGY AND SPACE: A COMPREHENSIVE OVERVIEW
#
# === THE BIG BANG THEORY ===
#
# The Big Bang theory is the prevailing cosmological model explaining the origin of the universe. According to this theory, the universe began approximately 13.8 billion years ago from an extremely hot, dense state and has been expanding ever since. This expansion was first observed by Edwin Hubble in 1929 when he discovered that galaxies are moving away from us, with more distant galaxies receding faster.
#
# The evidence supporting the Big Bang includes the cosmic microwave background radiation (CMB), which is the afterglow of the initial explosion, discovered by Arno Penzias and Robert Wilson in 1964. The CMB has a temperature of about 2.7 Kelvin and is remarkably uniform across the sky, with tiny fluctuations that seeded the formation of galaxies.
#
# In the first fraction of a second after the Big Bang, the universe underwent a period of rapid expansion called cosmic inflation. This theory, proposed by Alan Guth in 1980, explains why the universe appears so uniform on large scales and solves several problems with the original Big Bang model.
#
# === THE STRUCTURE OF THE UNIVERSE ===
#
# The universe is organized in a hierarchical structure. At the smallest scale, we have planets orbiting stars. Stars are grouped into galaxies, which typically contain hundreds of billions of stars. Our galaxy, the Milky Way, is a barred spiral galaxy containing between 200 to 400 billion stars and is about 100,000 light-years in diameter.
#
# Galaxies themselves are organized into groups and clusters. Our Milky Way is part of the Local Group, which includes the Andromeda Galaxy and about 50 other smaller galaxies. Galaxy clusters can contain thousands of galaxies and are the largest gravitationally bound structures in the universe.
#
# On even larger scales, galaxy clusters form superclusters, which are arranged in vast filaments and sheets surrounding enormous voids. This cosmic web structure extends throughout the observable universe, which has a diameter of about 93 billion light-years.
#
# === DARK MATTER AND DARK ENERGY ===
#
# One of the most profound discoveries in modern cosmology is that the ordinary matter we can see makes up only about 5% of the universe's total energy content. The remaining 95% consists of dark matter (about 27%) and dark energy (about 68%).
#
# Dark matter is a mysterious form of matter that doesn't emit, absorb, or reflect light, making it invisible to electromagnetic radiation. We know it exists because of its gravitational effects on visible matter, radiation, and the large-scale structure of the universe. Dark matter forms halos around galaxies and provides the gravitational scaffolding for galaxy formation.
# ================================================================================
#
#
# ================================================================================
# CHUNK [4] - 2649 characters
# ================================================================================
# === FUTURE OF THE UNIVERSE ===
#
# The ultimate fate of the universe depends on its density and the nature of dark energy. Current observations suggest the universe will continue expanding forever, with the expansion accelerating due to dark energy. In this "Big Freeze" scenario, stars will eventually exhaust their fuel, and the universe will become cold and dark.
#
# In the distant future, trillions of years from now, star formation will cease as gas clouds are exhausted. Existing stars will burn out, galaxies will fade, and the universe will enter the Degenerate Era, dominated by stellar remnants. Even farther in the future, in the Black Hole Era, black holes will be the dominant structures, until they too evaporate through Hawking radiation.
#
# However, our understanding of dark energy is still incomplete, and future observations might reveal surprising twists in the universe's fate.
#
# === SPACE EXPLORATION ===
#
# Human space exploration began in 1961 when Yuri Gagarin became the first human in space. The Apollo program achieved the first crewed Moon landing in 1969, with Neil Armstrong and Buzz Aldrin walking on the lunar surface.
#
# Since then, humans have maintained a continuous presence in low Earth orbit, first on space stations like Skylab and Mir, and currently on the International Space Station, which has been continuously occupied since 2000.
#
# Robotic missions have explored every planet in our Solar System. Notable missions include the Voyager probes, which have left the Solar System and entered interstellar space; the Mars rovers, which have discovered evidence of ancient water on Mars; and the New Horizons mission, which flew by Pluto in 2015, revealing a geologically active world.
#
# === COSMIC TIMELINE ===
#
# The history of the universe can be divided into distinct epochs. The Planck Epoch, lasting only 10^-43 seconds, is the earliest period we can theoretically describe. During the Quark Epoch, the universe was a hot soup of fundamental particles. The universe became transparent to light about 380,000 years after the Big Bang, releasing the cosmic microwave background radiation we observe today.
#
# The first stars formed about 100-200 million years after the Big Bang, ending the cosmic Dark Ages. These early stars were massive and short-lived, producing the first heavy elements through nuclear fusion and supernova explosions.
#
# Galaxies began forming and evolving through mergers and interactions. Our Solar System formed about 9 billion years after the Big Bang. Today, at 13.8 billion years, the universe continues to expand and evolve, with new stars forming and galaxies merging in an ongoing cosmic dance.
# ================================================================================
#
#
# 🖼️  IMAGES: 0
#
# 📊 TABLES: 0
#
# 📚 CITATIONS: 4
#   [1] cosmology_and_space.txt (pg.2) | chunk: 588f319a...
#   [2] cosmology_and_space.txt (pg.3) | chunk: ca62bab9...
#   [3] cosmology_and_space.txt (pg.1) | chunk: 6650e7b4...
#   [4] cosmology_and_space.txt (pg.4) | chunk: ca170e5d...
#
# ================================================================================
# ✅ Total: 4 texts (10,480 chars), 0 images, 0 tables, 4 citations
# ================================================================================
#
# step: tools
# content: [{'type': 'text', 'text': "The document provides a detailed overview of black holes, describing them as regions of spacetime where gravity is so intense that nothing, not even light, can escape. They are formed primarily when massive stars collapse at the end of their life cycles, among other processes that may have occurred in the early universe. The boundary surrounding a black hole is referred to as the event horizon, which marks the point of no return for any matter or information.\n\nThere are two main types of black holes mentioned:\n\n1. **Stellar-mass black holes**: These typically have masses ranging from 5 to 100 times the mass of the Sun.\n2. **Supermassive black holes**: These are usually found at the centers of galaxies and can possess masses from millions to billions of solar masses. A notable example is Sagittarius A*, the supermassive black hole at the center of the Milky Way, which has a mass of approximately 4 million solar masses.\n\nAdditionally, a landmark event in black hole research was highlighted as the first direct image of a black hole's shadow, achieved by the Event Horizon Telescope collaboration in 2019. This image focused on the supermassive black hole in the galaxy M87 and validated many concepts put forth by Einstein's general theory of relativity."}]
# step: tools
# content: [{'type': 'text', 'text': "Here are notable black hole discoveries and related developments since 2023:\n\n1. **First Evidence of a Black Hole Tearing Apart a White Dwarf** (Published February 25, 2026):\n   Astronomers captured the first direct evidence of an intermediate-mass black hole consuming a white dwarf star. This discovery, made by the Einstein Probe space telescope in July 2025, highlights the dynamic interactions between black holes and stars, opening new avenues for understanding black hole formation. [Read more here](https://dailygalaxy.com/2026/02/first-evidence-black-hole-rips-white-dwarf/).\n\n2. **Doubling the Catalog of Black Hole Collisions** (Published March 6, 2026):\n   The LIGO-Virgo-KAGRA collaboration reported a significant increase in detected gravitational waves from black hole and neutron star collisions. This expansion of the Gravitational-Wave Transient Catalog includes 128 sources detected during an observational run from May 2023 to January 2024, enhancing our understanding of black hole formation and cosmological evolution. [Read more here](https://www.space.com/astronomy/black-holes/the-universe-is-humming-with-ripples-in-spacetime-scientists-just-doubled-our-catalog-of-black-hole-and-neutron-star-collisions).\n\n3. **Potential Evidence of Primordial Black Holes** (Published March 25, 2026):\n   An unusual gravitational wave signal detected by LIGO may indicate the existence of subsolar-mass black holes, potentially primordial black holes formed shortly after the Big Bang. This finding could contribute to our understanding of dark matter. [Read more here](https://phys.org/news/2026-03-unusual-primordial-black-holes.html).\n\n4. **Colliding Black Holes Triggering Light Production** (Published March 17, 2026):\n   A detailed analysis of a gravitational wave event, associated with a black hole merger, suggested that for the first time, light signals were detected alongside a merger event. This could lead to new insights into the physics surrounding black hole mergers. [Read more here](https://www.sciencealert.com/astronomers-may-have-seen-colliding-black-holes-trigger-a-blaze-of-light).\n\n5. **Changes in a Distant Galaxy's Supermassive Black Hole Activity** (Published March 26, 2026):\n   A galaxy located approximately 10 billion light-years away exhibited a rapid drop in brightness attributed to a significant decrease in gas accretion onto its central supermassive black hole. This challenges long-held theories about the accretion rates of supermassive black holes. [Read more here](https://phys.org/news/2026-03-distant-galaxy-decades-supermassive-black.html).\n\nThese recent findings represent a significant advancement in our understanding of black holes and their interactions in the universe."}]
# step: model
# content: [{'type': 'text', 'text': "### Overview from Your Document on Black Holes\n\nThe document provides extensive insights into black holes, characterizing them as regions of spacetime from which nothing, not even light, can escape due to extreme gravitational forces. Here are the key points mentioned:\n\n- **Formation**: Black holes primarily form when massive stars collapse at the end of their life cycles, along with other processes that may have occurred in the early universe.\n- **Event Horizon**: The boundary around a black hole is known as the event horizon, marking the point beyond which no matter or information can return.\n- **Types of Black Holes**:\n  1. **Stellar-mass Black Holes**: These typically have masses ranging from 5 to 100 times that of the Sun.\n  2. **Supermassive Black Holes**: Usually found at the centers of galaxies, they can have masses ranging from millions to billions of solar masses (e.g., Sagittarius A* with a mass of about 4 million solar masses).\n  \nNoteworthy is the first direct image of a black hole’s shadow taken by the Event Horizon Telescope in 2019, focusing on the supermassive black hole in the galaxy M87, which validated concepts from Einstein's general theory of relativity.\n\n---\n\n### Recent Black Hole Discoveries (since 2023)\n\nSeveral exciting discoveries concerning black holes have emerged over the last three years:\n\n1. **First Evidence of a Black Hole Tearing Apart a White Dwarf** (Feb 25, 2026):\n   - Observations from the Einstein Probe indicated an intermediate-mass black hole consuming a white dwarf star, offering insights into the interactions between black holes and stars. [Read more](https://dailygalaxy.com/2026/02/first-evidence-black-hole-rips-white-dwarf/).\n   \n2. **Doubling the Catalog of Black Hole Collisions** (Mar 6, 2026):\n   - The LIGO-Virgo-KAGRA collaboration reported a significant increase in detected gravitational waves from black hole and neutron star collisions, expanding the Gravitational-Wave Transient Catalog. [Read more](https://www.space.com/astronomy/black-holes/the-universe-is-humming-with-ripples-in-spacetime-scientists-just-doubled-our-catalog-of-black-hole-and-neutron-star-collisions).\n   \n3. **Potential Evidence of Primordial Black Holes** (Mar 25, 2026):\n   - A gravitational wave signal detected by LIGO suggests possible subsolar-mass primordial black holes, potentially formed shortly after the Big Bang, offering new insights into dark matter. [Read more](https://phys.org/news/2026-03-unusual-primordial-black-holes.html).\n   \n4. **Colliding Black Holes Triggering Light Production** (Mar 17, 2026):\n   - A gravitational wave event associated with a black hole merger has been linked to the production of light signals for the first time. [Read more](https://www.sciencealert.com/astronomers-may-have-seen-colliding-black-holes-trigger-a-blaze-of-light).\n   \n5. **Changes in a Distant Galaxy's Supermassive Black Hole Activity** (Mar 26, 2026):\n   - A distant galaxy exhibited a rapid drop in brightness due to reduced gas accretion onto its central supermassive black hole, challenging existing theories about accretion rates. [Read more](https://phys.org/news/2026-03-distant-galaxy-decades-supermassive-black.html).\n\nThese findings mark significant advancements in our understanding of black holes and their roles in the universe."}]
